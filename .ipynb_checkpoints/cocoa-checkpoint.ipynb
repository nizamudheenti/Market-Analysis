# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
# Out:
# Using TensorFlow backend.

# %%
data=pd.read_csv('pinksheet.csv')

# %%
data1=data[1:721]
data2=data1[['Unnamed: 0','Cocoa']]
data2=data2.rename(columns={"Unnamed: 0":"date"})
data2.head(10)
# Out:
#        date Cocoa
# 1   1960M01  0.63
# 2   1960M02  0.61
# 3   1960M03  0.58
# 4   1960M04   0.6
# 5   1960M05   0.6
# 6   1960M06  0.59
# 7   1960M07   0.6
# 8   1960M08  0.59
# 9   1960M09  0.58
# 10  1960M10  0.59

# %%
data2['date']=data2['date'].str.replace("M","-")
data2['date']=pd.to_datetime(data2.date,format='%Y-%m')

# %%
data2.head()
# Out:
#            Cocoa
# date
# 1960-01-01  0.63
# 1960-02-01  0.61
# 1960-03-01  0.58
# 1960-04-01   0.6
# 1960-05-01   0.6

# %%
data2.index = data2.date
data2.drop('date', axis=1, inplace=True)

# %%
#dataset[0:400,:]

# %%
dataset = data2.values
train = dataset[0:400]
valid = dataset[400:]
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)
x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2)
closing_price = model.predict(x_train)
closing_price = scaler.inverse_transform(closing_price)
# Out:
# Epoch 1/1
#  - 36s - loss: 0.0114

# %%
rms=np.sqrt(np.mean(np.power((closing_price),2)))
rms
# Out:
# 1.6259376

# %%
#for plotting
train = data2[:400]
valid = data2[400:]
x_train['Predictions'] = closing_price
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-112-ee401492b573> in <module>
#       2 train = data2[:400]
#       3 valid = data2[400:]
# ----> 4 x_train['Predictions'] = closing_price
#       5 plt.plot(train['Close'])
#       6 plt.plot(valid[['Close','Predictions']])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
#for plotting
train = data2[:400]
valid = data2[400:]
len(train)
len(X_test)
# Out:
# 700

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=[20,10])
sns.scatterplot(data=data2[650:],x='date',y='Cocoa')
plt.xlabel("MONTH")
plt.ylabel('PRICE)')
plt.show()

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(np.asmatrix(data2['date']).reshape(-1,1),np.asmatrix(data2['Cocoa']).reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-d7415bf11c55> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 lr=LinearRegression()
# ----> 3 lr.fit(np.asmatrix(data2['date']).reshape(-1,1),np.asmatrix(data2['Cocoa']).reshape(-1,1))
#
# ~\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in asmatrix(data, dtype)
#      69
#      70     """
# ---> 71     return matrix(data, dtype=dtype, copy=False)
#      72
#      73
#
# ~\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in __new__(subtype, data, dtype, copy)
#     164         ret = N.ndarray.__new__(subtype, shape, arr.dtype,
#     165                                 buffer=arr,
# --> 166                                 order=order)
#     167         return ret
#     168
#
# ValueError: cannot include dtype 'M' in a buffer

# %%
data3=[731]
pre=lr.predict(np.asmatrix(data2['date']).reshape(-1,1))
from sklearn.metrics import mean_squared_error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-5fd3646e9c17> in <module>
#       1 data3=[731]
# ----> 2 pre=lr.predict(np.asmatrix(data2['date']).reshape(-1,1))
#       3 from sklearn.metrics import mean_squared_error
#
# ~\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in asmatrix(data, dtype)
#      69
#      70     """
# ---> 71     return matrix(data, dtype=dtype, copy=False)
#      72
#      73
#
# ~\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in __new__(subtype, data, dtype, copy)
#     164         ret = N.ndarray.__new__(subtype, shape, arr.dtype,
#     165                                 buffer=arr,
# --> 166                                 order=order)
#     167         return ret
#     168
#
# ValueError: cannot include dtype 'M' in a buffer

# %%
#pre
mean_squared_error(np.asmatrix(data2['Cocoa']).reshape(-1,1),pre)
# Out:
# 0.5382918814422573

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor(n_estimators=250,max_depth=8,random_state=1111)

# %%
X=np.asmatrix(data2['date']).reshape(-1,1)
y=np.asmatrix(data2['Cocoa']).reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-6e3f05a72975> in <module>
# ----> 1 X=np.asmatrix(data2['date']).reshape(-1,1)
#       2 y=np.asmatrix(data2['Cocoa']).reshape(-1,1)
#
# ~\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in asmatrix(data, dtype)
#      69
#      70     """
# ---> 71     return matrix(data, dtype=dtype, copy=False)
#      72
#      73
#
# ~\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in __new__(subtype, data, dtype, copy)
#     164         ret = N.ndarray.__new__(subtype, shape, arr.dtype,
#     165                                 buffer=arr,
# --> 166                                 order=order)
#     167         return ret
#     168
#
# ValueError: cannot include dtype 'M' in a buffer

# %%
rfr.fit(X,y)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=8,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=250,
#                       n_jobs=None, oob_score=False, random_state=1111,
#                       verbose=0, warm_start=False)

# %%
pre2=rfr.predict(np.asmatrix(data2['date']).reshape(-1,1))
mean_squared_error(np.asmatrix(data2['Cocoa']).reshape(-1,1),pre2)
# Out:
# 0.0072378706368629465

# %%
pred3=rfr.predict(X)
#pd.DataFrame(y,pred3)
plt.plot(X, y, 'b-',
         label='Actual')
plt.plot(X, pred3, 'r-',
         label='predicted')
plt.legend(loc='upper right')
plt.xlabel('MONTH')
plt.ylabel('PRIZE')

plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gr=GradientBoostingRegressor(loss='quantile', alpha=0.6,
                                n_estimators=250, max_depth=8,
                                learning_rate=0.15)

# %%
gr.fit(X,y)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor(alpha=0.6, criterion='friedman_mse', init=None,
#                           learning_rate=0.15, loss='quantile', max_depth=8,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=250,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
pred4=gr.predict(X)

# %%
mean_squared_error(y,pred4)
# Out:
# 0.005689127787979648

# %%
plt.plot(X, y, 'b-',
         label='Actual')
plt.plot(X, pred4, 'r-',
         label='predicted')
plt.legend(loc='upper right')
plt.xlabel('MONTH')
plt.ylabel('PRIZE')

plt.show()

# %%
from sklearn.svm import SVR

# %%
svr=SVR(C=1.0, epsilon=0.2)

# %%
svr.fit(X,y)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred5=svr.predict(X)

# %%
plt.plot(X, y, 'b-',
         label='Actual')
plt.plot(X, pred5, 'r-',
         label='predicted')
plt.legend(loc='upper right')
plt.xlabel('MONTH')
plt.ylabel('PRIZE')

plt.show()

# %%
svr_rbf = SVR(kernel='rbf', C=1, gamma=0.1, epsilon=.1)
svr_lin = SVR(kernel='linear', C=1, gamma='auto')
svr_poly = SVR(kernel='poly', C=1, gamma='auto', degree=3, epsilon=.1,
               coef0=1)

# %%
svr_rbf.fit(X,y)
svr_lin.fit(X,y)
svr_poly.fit(X,y)

# %%
rbf=svr_rbf.predict(X)
lin=svr_lin.predict(X)
poly=svr_poly.predict(X)

# %%
from sklearn.linear_model import BayesianRidge,ARDRegression
clf = BayesianRidge(compute_score=True)
clf.fit(X, y)
pred6=clf.predict(X)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plt.plot(X, y, 'b-',
         label='Actual')
plt.plot(X, pred6, 'r-',
         label='predicted')
plt.legend(loc='upper right')
plt.xlabel('MONTH')
plt.ylabel('PRIZE')

plt.show()

# %%
clf = ARDRegression()
clf.fit(X, y)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ARDRegression(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#               fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#               normalize=False, threshold_lambda=10000.0, tol=0.001,
#               verbose=False)

# %%
pred7=clf.predict(X)
plt.plot(X, y, 'b-',
         label='Actual')
plt.plot(X, pred7, 'r-',
         label='predicted')
plt.legend(loc='upper right')
plt.xlabel('MONTH')
plt.ylabel('PRIZE')

plt.show()

# %%
from sklearn.linear_model import SGDRegressor
clf =SGDRegressor(max_iter=1000)
clf.fit(X, y)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='squared_loss', max_iter=1000,
#              n_iter_no_change=5, penalty='l2', power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
pred8=clf.predict(X)

# %%
plt.plot(X, y, 'b-',
         label='Actual')
plt.plot(X, pred8, 'r-',
         label='predicted')
plt.legend(loc='upper right')
plt.xlabel('MONTH')
plt.ylabel('PRIZE')

plt.show()

# %%
pred_data=[732,733]
gr.predict(np.asmatrix(pred_data).reshape(-1,1))
# Out:
# array([2.44, 2.44])
